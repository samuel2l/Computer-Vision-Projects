# %%
import cv2

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
# %matplotlib inline

# %%
Image(filename='IMG_2777.JPG')
#Image class shows actual dimensions of image without resizing

# %%
cv2.imread('IMG_2777.JPG',0)
# Out:
# array([[109, 109, 109, ...,  67,  70,  72],
#        [114, 114, 113, ...,  72,  75,  78],
#        [119, 119, 118, ...,  77,  81,  84],
#        ...,
#        [120, 116, 122, ..., 171, 171, 171],
#        [131, 119, 124, ..., 169, 170, 171],
#        [137, 119, 125, ..., 168, 170, 172]], dtype=uint8)
