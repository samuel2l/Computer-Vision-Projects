# %%
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np

image_path = '/Users/samuel/realtime_obj_detection/obj detection/iimg.jpg'

img = cv2.imread(image_path)

reader = easyocr.Reader(['en'], gpu=False)

text_ = reader.readtext(img)
print(text_)

threshold = 0
for t_, t in enumerate(text_):
    print(t)

    bbox, text, score = t

    if score > threshold:
        cv2.rectangle(img, bbox[0], bbox[2], (0, 255, 0), 5)
        cv2.putText(img, text, bbox[0], cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ...

# %%
#employing text to speech
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np
import pyttsx3  # For text-to-speech

# Initialize the TTS engine
engine = pyttsx3.init()

# Load the image
image_path = '/Users/samuel/realtime_obj_detection/obj detection/IMG_2834.JPG'
img = cv2.imread(image_path)

# Initialize EasyOCR reader
reader = easyocr.Reader(['en'], gpu=False)

# Perform text detection
text_ = reader.readtext(img)
print(text_)

threshold = 0

for t_, t in enumerate(text_):
    print(t)

    bbox, text, score = t

    if score > threshold:
        # Draw a rectangle around detected text
        cv2.rectangle(img, bbox[0], bbox[2], (0, 255, 0), 5)
        cv2.putText(img, text, bbox[0], cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)

        # Use pyttsx3 to convert the detected text to speech
        engine.say(text)  # Queue the text to be spoken
        engine.runAndWait()  # Speak the text immediately

# Display the image with bounding boxes
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[347, 1260], [1039, 1260], [1039, 1480], [347, 1480]], 'DQEAMBL', 0.06042528735622697), ([[446, 1433], [978, 1433], [978, 1795], [446, 1795]], '15', 0.9996137038436425)]
# ([[347, 1260], [1039, 1260], [1039, 1480], [347, 1480]], 'DQEAMBL', 0.06042528735622697)
# ([[446, 1433], [978, 1433], [978, 1795], [446, 1795]], '15', 0.9996137038436425)

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np
import pyttsx3  # Import the text-to-speech library

# Initialize the text-to-speech engine
engine = pyttsx3.init()

image_path = '/Users/samuel/realtime_obj_detection/obj detection/iimg.jpg'

# Read the image
img = cv2.imread(image_path)

# Check if the image is loaded properly
if img is None:
    print("Error: Image not found or unable to load.")
else:
    reader = easyocr.Reader(['en'], gpu=False)

    # Perform text detection
    text_ = reader.readtext(img)

    # Print the detected text
    print("Detected text:", text_)

    threshold = 0
    detected_texts = []  # List to store detected texts
    for t_, t in enumerate(text_):
        print(t)

        # Unpack the bounding box, text, and score
        bbox, text, score = t

        # Draw bounding box and text if the score is above the threshold
        if score > threshold:
            cv2.rectangle(img, (int(bbox[0][0]), int(bbox[0][1])), (int(bbox[2][0]), int(bbox[2][1])), (0, 255, 0), 5)
            cv2.putText(img, text, (int(bbox[0][0]), int(bbox[0][1])), cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)
            detected_texts.append(text)  # Add detected text to the list

    # Speak out the detected texts
    if detected_texts:
        # Join the detected texts into a single string
        full_text = ' '.join(detected_texts)
        print("Reading text aloud: ", full_text)  # Print the text that will be read
        engine.say(full_text)  # Use the text-to-speech engine to say the detected text
        engine.runAndWait()  # Wait for the speaking to finish

    # Show the image with detected text
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # Hide axes
    plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ...

# %%
#trying a page from a book
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np

image_path = '/Users/samuel/realtime_obj_detection/obj detection/iimg.jpg'

# Read the image
img = cv2.imread(image_path)

# Check if the image is loaded properly
if img is None:
    print("Error: Image not found or unable to load.")
else:
    reader = easyocr.Reader(['en'], gpu=False)

    # Perform text detection
    text_ = reader.readtext(img)

    # Print the detected text
    print("Detected text:", text_)

    threshold = 0
    for t_, t in enumerate(text_):
        print(t)

        # Unpack the bounding box, text, and score
        bbox, text, score = t

        # Draw bounding box and text if the score is above the threshold
        if score > threshold:
            cv2.rectangle(img, (int(bbox[0][0]), int(bbox[0][1])), (int(bbox[2][0]), int(bbox[2][1])), (0, 255, 0), 5)
            cv2.putText(img, text, (int(bbox[0][0]), int(bbox[0][1])), cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)

    # Show the image with detected text
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # Hide axes
    plt.show()
